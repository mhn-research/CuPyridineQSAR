# %%
# Import required libraries
import joblib
import os
import pandas as pd
import numpy as np

# Load the saved model
home_dir = os.path.join(os.path.dirname(os.path.abspath('__file__')))

model_path = home_dir + '/Library/01_LinearRegression.mdl'  # Update with your actual path
lr_model = joblib.load(model_path)
print("Model loaded successfully!")

# Load new data for prediction
new_data_path = home_dir + '/Data/test.csv'  # Update with your actual path
test_data = pd.read_csv(new_data_path)

X_test = test_data[["L1_MolWt", "L1_MolLogP", "L1_NumHDonors", "L1_NumHAcceptors", "L1_TPSA", "L1_NumRotatableBonds", "L1_NumAromaticRings", "L1_NumAliphaticRings", "L1_FractionCSP3", "L1_HeavyAtomCount", "L2_MolWt", "L2_MolLogP", "L2_NumHDonors", "L2_NumHAcceptors", "L2_TPSA", "L2_NumRotatableBonds", "L2_NumAromaticRings", "L2_NumAliphaticRings", "L2_FractionCSP3", "L2_HeavyAtomCount", "L3_MolWt", "L3_MolLogP", "L3_NumHDonors", "L3_NumHAcceptors", "L3_TPSA", "L3_NumRotatableBonds", "L3_NumAromaticRings", "L3_NumAliphaticRings", "L3_FractionCSP3", "L3_HeavyAtomCount"]]

# Make predictions
predictions = lr_model.predict(X_test)
test_data['predicted_pIC50'] = predictions.round(2)

# Save results
test_data.to_csv(home_dir + '/Results/prediction.csv', index=False)
print("Predictions completed and saved!")
# Out:
# Model loaded successfully!
# New data shape: (140, 31)
# New data preview:
#    pIC50  L1_MolWt  L1_MolLogP  L1_NumHDonors  L1_NumHAcceptors   L1_TPSA  \
# 0   5.90  0.884510    0.025302              0          2.726750  0.719229
# 1   4.98 -0.547641   -0.012651              0         -1.142287 -0.649530
# 2   5.09 -0.547641   -0.012651              0         -1.142287 -0.649530
# 3   5.26 -0.547641   -0.012651              0         -1.142287 -0.649530
# 4   4.94 -0.324626    0.441041              0         -1.142287 -0.649530
#
#    L1_NumRotatableBonds  L1_NumAromaticRings  L1_NumAliphaticRings  \
# 0              2.192386            -0.264327                   0.0
# 1             -0.461222            -0.264327                   0.0
# 2             -0.461222            -0.264327                   0.0
# 3             -0.461222            -0.264327                   0.0
# 4             -0.461222            -0.264327                   0.0
#
# ...
